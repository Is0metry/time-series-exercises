# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from importlib import reload
import warnings
warnings.simplefilter("ignore")
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
store_data = pd.read_csv('~/Downloads/tsa_store_data.csv')
store_data.head()
# Out:
#    store_id  item_id   item_upc14   item_upc12 item_brand  \
# 0         1        1  35200264013  35200264013   Riceland
# 1         1        1  35200264013  35200264013   Riceland
# 2         1        1  35200264013  35200264013   Riceland
# 3         1        1  35200264013  35200264013   Riceland
# 4         1        1  35200264013  35200264013   Riceland
#
#                         item_name  item_price  sale_id   sale_date  \
# 0  Riceland American Jazmine Rice        0.84        1  2013-01-01
# 1  Riceland American Jazmine Rice        0.84        2  2013-01-02
# 2  Riceland American Jazmine Rice        0.84        3  2013-01-03
# 3  Riceland American Jazmine Rice        0.84        4  2013-01-04
# 4  Riceland American Jazmine Rice        0.84        5  2013-01-05
#
#    sale_amount           store_address  store_zipcode   store_city store_state
# 0           13  12125 Alamo Ranch Pkwy          78253  San Antonio          TX
# ...

# %% [markdown]
# The end result of this exercise should be a file named prepare.py.
#
# Using your store items data:
#
# Convert date column to datetime format.

# %%
store_data.sale_date = pd.to_datetime(store_data.sale_date)

# %% [markdown]
# Plot the distribution of sale_amount and item_price.

# %%
fig,axs= plt.subplots(2,1)
sns.histplot(data=store_data,x='sale_amount',ax=axs[0])
sns.histplot(data=store_data,x='item_price',ax=axs[1])
# Out:
# <AxesSubplot: xlabel='item_price', ylabel='Count'>

# %% [markdown]
# Set the index to be the datetime variable.

# %%
store_data.index = store_data.sale_date

# %% [markdown]
# Add a 'month' and 'day of week' column to your dataframe.

# %%
store_data['month'] = store_data.index.month_name()
store_data['day_of_week'] = store_data.index.day_name()
store_data.head()
# Out:
#             store_id  item_id   item_upc14   item_upc12 item_brand  \
# sale_date
# 2013-01-01         1        1  35200264013  35200264013   Riceland
# 2013-01-02         1        1  35200264013  35200264013   Riceland
# 2013-01-03         1        1  35200264013  35200264013   Riceland
# 2013-01-04         1        1  35200264013  35200264013   Riceland
# 2013-01-05         1        1  35200264013  35200264013   Riceland
#
#                                  item_name  item_price  sale_id  sale_date  \
# sale_date
# 2013-01-01  Riceland American Jazmine Rice        0.84        1 2013-01-01
# 2013-01-02  Riceland American Jazmine Rice        0.84        2 2013-01-02
# 2013-01-03  Riceland American Jazmine Rice        0.84        3 2013-01-03
# 2013-01-04  Riceland American Jazmine Rice        0.84        4 2013-01-04
# 2013-01-05  Riceland American Jazmine Rice        0.84        5 2013-01-05
#
#             sale_amount           store_address  store_zipcode   store_city  \
# ...

# %% [markdown]
# Add a column to your dataframe, sales_total, which is a derived from sale_amount (total items) and item_price.

# %%
store_data['sales_total'] = store_data.sale_amount * store_data.item_price
store_data.head()
# Out:
#             store_id  item_id   item_upc14   item_upc12 item_brand  \
# sale_date
# 2013-01-01         1        1  35200264013  35200264013   Riceland
# 2013-01-02         1        1  35200264013  35200264013   Riceland
# 2013-01-03         1        1  35200264013  35200264013   Riceland
# 2013-01-04         1        1  35200264013  35200264013   Riceland
# 2013-01-05         1        1  35200264013  35200264013   Riceland
#
#                                  item_name  item_price  sale_id  sale_date  \
# sale_date
# 2013-01-01  Riceland American Jazmine Rice        0.84        1 2013-01-01
# 2013-01-02  Riceland American Jazmine Rice        0.84        2 2013-01-02
# 2013-01-03  Riceland American Jazmine Rice        0.84        3 2013-01-03
# 2013-01-04  Riceland American Jazmine Rice        0.84        4 2013-01-04
# 2013-01-05  Riceland American Jazmine Rice        0.84        5 2013-01-05
#
#             sale_amount           store_address  store_zipcode   store_city  \
# ...

# %% [markdown]
# Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %% [markdown]
# Using the OPS data acquired in the Acquire exercises opsd_germany_daily.csv, complete the following:

# %%
ops_df = pd.read_csv('https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv')
ops_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4383 entries, 0 to 4382
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         4383 non-null   object
#  1   Consumption  4383 non-null   float64
#  2   Wind         2920 non-null   float64
#  3   Solar        2188 non-null   float64
#  4   Wind+Solar   2187 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 171.3+ KB

# %% [markdown]
# Convert date column to datetime format.

# %%
ops_df.Date = pd.to_datetime(ops_df.Date)

# %% [markdown]
# Plot the distribution of each of your variables.

# %%
fig,axs = plt.subplots(2,2)
for i,s in enumerate(['Consumption','Wind','Solar','Wind+Solar']):
    sns.histplot(data=ops_df,x=s,ax=axs[(i)//2][(i%2)])
plt.show()

# %% [markdown]
# Set the index to be the datetime variable.

# %%
ops_df.index = ops_df.Date

# %% [markdown]
# Add a month and a year column to your dataframe.

# %% [markdown]
# Fill any missing values.
# Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.
